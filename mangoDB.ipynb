# %%
# !pip install pymongo
# Out:
# ...
#    ---------------------------------------- 0.0/485.1 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/485.1 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/485.1 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/485.1 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/485.1 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/485.1 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/485.1 kB ? eta -:--:--
#    ----------- -------------------------- 143.4/485.1 kB 473.7 kB/s eta 0:00:01
#    ----------- -------------------------- 143.4/485.1 kB 473.7 kB/s eta 0:00:01
#    ------------- ------------------------ 174.1/485.1 kB 436.9 kB/s eta 0:00:01
#    --------------- ---------------------- 194.6/485.1 kB 472.6 kB/s eta 0:00:01
#    ---------------- --------------------- 204.8/485.1 kB 402.0 kB/s eta 0:00:01
# ...

# %%
from pymongo import MongoClient
from datetime import datetime

client = MongoClient('mongodb+srv://manasjain1122:1234@cluster0.bbnmweo.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
db = client['SchoolManagement']  # Rename the database for clarity

# Collections (like tables)
students_collection = db['Students']
teachers_collection = db['Teachers']
courses_collection = db['Courses']

# --- Student Document Example ---
student_document = {
    "student_id": "S001",  
    "name": {
        "first_name": "Shri",
        "last_name": "Patil"
    },
    "gender": "Male",
    "date_of_birth": datetime(2008, 5, 15),
    "address": {
        "street": "123 Main Street",
        "city": "Pune",
        "state": "Maharashtra",
        "pincode": "411001"
    },
    "contact": {
        "email": "shri.patil@example.com",
        "phone": "9876543210"
    },
    "academic_records": [
        {
            "year": 2023,
            "grade": 10,
            "marks": {
                "total": 93.80,
                "subjects": { 
                    "math": 95,
                    "science": 92,
                    # ... other subjects
                }
            }
        }
        # Add more academic records as needed
    ]
}

# --- Teacher Document Example ---
teacher_document = {
    "teacher_id": "T001",
    "name": {
        "first_name": "Neha",
        "last_name": "Sharma"
    },
    # ... (similar fields as student, but add teacher-specific info)
    "subjects_taught": ["Math", "Physics"]
}

# --- Course Document Example ---
course_document = {
    "course_id": "C001",
    "name": "Mathematics",
    "teacher_id": "T001",  # Link to the teacher teaching the course
    "students_enrolled": ["S001", "S002"]  # List of student IDs enrolled
}

# --- Inserting Documents ---
students_collection.insert_one(student_document)
teachers_collection.insert_one(teacher_document)
courses_collection.insert_one(course_document)

# --- Finding Documents ---
all_students = list(students_collection.find())
print("All Students:")
for student in all_students:
    print(student)

# --- Updating a Document ---
students_collection.update_one(
    {"student_id": "S001"},
    {"$set": {"academic_records.0.marks.total": 95.0}}  # Update 10th marks
)

client.close()
# Out:
# All Students:
# {'_id': ObjectId('66506a2f36dd9424787e794b'), 'student_id': 'S001', 'name': {'first_name': 'Shri', 'last_name': 'Patil'}, 'gender': 'Male', 'date_of_birth': datetime.datetime(2008, 5, 15, 0, 0), 'address': {'street': '123 Main Street', 'city': 'Pune', 'state': 'Maharashtra', 'pincode': '411001'}, 'contact': {'email': 'shri.patil@example.com', 'phone': '9876543210'}, 'academic_records': [{'year': 2023, 'grade': 10, 'marks': {'total': 93.8, 'subjects': {'math': 95, 'science': 92}}}]}
